# %% [markdown]
# # Extrai Tweets

# %%
# !pip install tweepy datetime

# %% [markdown]
# # Play

# %%
# !python get_tweets.py

# %% [markdown]
# # Entendendo a estrutura do formato JSON

# %%
import json

# %%
# Abrir o arquivo de tweets as linhas
with open('collected_tweets_2020-11-21-19-27-40.txt', 'r') as file:
    tweets = file.readlines()

# %%
# fazendo um parse do tweet para um formato json e exporta arquivo
with open ('tweet.json', 'w') as f:
    json.dump(
      json.loads(json.loads(tweets[0])), f
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-ce8fea21e635> in <module>
#       2 with open ('tweet.json', 'w') as f:
#       3     json.dump(
# ----> 4       json.loads(json.loads(tweets[0])), f
#       5 )
#
# IndexError: list index out of range

# %%
parse_tweets = [json.loads(json.loads(i)) for i in tweets]

# %%
# quantidade de tweets coletados
len(parse_tweets)
# Out:
# 5677

# %% [markdown]
# # Acessando as chaves do Json (dicionário)

# %%
primeirotweet = parse_tweets[0]

# %%
primeirotweet.items()
# Out:
# dict_items([('created_at', 'Sat Nov 21 22:27:36 +0000 2020'), ('id', 1330276705408323590), ('id_str', '1330276705408323590'), ('text', "Only 1433 hours until the end of Donald Trump's presidency! #DontDrinkBleach #ImpeachTrump #TrumpCountdown #BidenHarris2020"), ('source', '<a href="http://www.TrumpCountDownComingSoon.com" rel="nofollow">The Trump Count Down</a>'), ('truncated', False), ('in_reply_to_status_id', None), ('in_reply_to_status_id_str', None), ('in_reply_to_user_id', None), ('in_reply_to_user_id_str', None), ('in_reply_to_screen_name', None), ('user', {'id': 822518858242134016, 'id_str': '822518858242134016', 'name': 'The Trump Countdown', 'screen_name': 'TrumpCountdown0', 'location': 'Washington, DC', 'url': None, 'description': "The unofficial countdown for Donald Trump's presidency.", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 354, 'friends_count': 9, 'listed_count': 6, 'favourites_count': 505, 'statuses_count': 33906, 'created_at': 'Fri Jan 20 18:59:12 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/822522107158556673/FMDFDwMr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822522107158556673/FMDFDwMr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822518858242134016/1484942903', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}), ('geo', None), ('coordinates', None), ('place', None), ('contributors', None), ('is_quote_status', False), ('quote_count', 0), ('reply_count', 0), ('retweet_count', 0), ('favorite_count', 0), ('entities', {'hashtags': [{'text': 'DontDrinkBleach', 'indices': [60, 76]}, {'text': 'ImpeachTrump', 'indices': [77, 90]}, {'text': 'TrumpCountdown', 'indices': [91, 106]}, {'text': 'BidenHarris2020', 'indices': [107, 123]}], 'urls': [], 'user_mentions': [], 'symbols': []}), ('favorited', False), ('retweeted', False), ('filter_level', 'low'), ('lang', 'en'), ('timestamp_ms', '1605997656572')])

# %%
# Acessa o created_at do tweet
# chave de primeiro nível (root)
primeirotweet['created_at']
# Out:
# 'Sat Nov 21 22:27:36 +0000 2020'

# %%
# Acessar a chave USER
primeirotweet['user']['id']
# Out:
# 822518858242134016

# %% [markdown]
# # Transformar os tweets em uma estrutura relacional analisável

# %%
import pandas as pd

# %%
teste = pd.DataFrame(primeirotweet)
teste.head()
# não funciona
# Out:
#                                            created_at                   id  \
# contributors_enabled   Sat Nov 21 22:27:36 +0000 2020  1330276705408323590
# created_at             Sat Nov 21 22:27:36 +0000 2020  1330276705408323590
# default_profile        Sat Nov 21 22:27:36 +0000 2020  1330276705408323590
# default_profile_image  Sat Nov 21 22:27:36 +0000 2020  1330276705408323590
# description            Sat Nov 21 22:27:36 +0000 2020  1330276705408323590
#
#                                     id_str  \
# contributors_enabled   1330276705408323590
# created_at             1330276705408323590
# default_profile        1330276705408323590
# default_profile_image  1330276705408323590
# description            1330276705408323590
#
#                                                                     text  \
# contributors_enabled   Only 1433 hours until the end of Donald Trump'...
# created_at             Only 1433 hours until the end of Donald Trump'...
# default_profile        Only 1433 hours until the end of Donald Trump'...
# default_profile_image  Only 1433 hours until the end of Donald Trump'...
# description            Only 1433 hours until the end of Donald Trump'...
#
#                                                                   source  \
# contributors_enabled   <a href="http://www.TrumpCountDownComingSoon.c...
# created_at             <a href="http://www.TrumpCountDownComingSoon.c...
# default_profile        <a href="http://www.TrumpCountDownComingSoon.c...
# default_profile_image  <a href="http://www.TrumpCountDownComingSoon.c...
# description            <a href="http://www.TrumpCountDownComingSoon.c...
#
#                        truncated in_reply_to_status_id  \
# contributors_enabled       False                  None
# created_at                 False                  None
# default_profile            False                  None
# default_profile_image      False                  None
# description                False                  None
#
#                       in_reply_to_status_id_str in_reply_to_user_id  \
# contributors_enabled                       None                None
# created_at                                 None                None
# default_profile                            None                None
# default_profile_image                      None                None
# description                                None                None
#
#                       in_reply_to_user_id_str  ... quote_count reply_count  \
# contributors_enabled                     None  ...           0           0
# created_at                               None  ...           0           0
# default_profile                          None  ...           0           0
# default_profile_image                    None  ...           0           0
# description                              None  ...           0           0
#
#                       retweet_count favorite_count entities favorited  \
# contributors_enabled              0              0      NaN     False
# created_at                        0              0      NaN     False
# default_profile                   0              0      NaN     False
# default_profile_image             0              0      NaN     False
# description                       0              0      NaN     False
#
#                        retweeted  filter_level  lang   timestamp_ms
# contributors_enabled       False           low    en  1605997656572
# created_at                 False           low    en  1605997656572
# default_profile            False           low    en  1605997656572
# default_profile_image      False           low    en  1605997656572
# description                False           low    en  1605997656572
#
# [5 rows x 27 columns]

# %%
df_tratado = pd.DataFrame(primeirotweet).reset_index(drop=True).iloc[:1]
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 22:27:36 +0000 2020  1330276705408323590  1330276705408323590
#
#                                                 text  \
# 0  Only 1433 hours until the end of Donald Trump'...
#
#                                               source  truncated  \
# 0  <a href="http://www.TrumpCountDownComingSoon.c...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ... quote_count reply_count retweet_count  \
# 0                    None  ...           0           0             0
#
#   favorite_count entities favorited  retweeted  filter_level  lang  \
# 0              0      NaN     False      False           low    en
#
#     timestamp_ms
# 0  1605997656572
#
# [1 rows x 27 columns]

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'quote_count', 'reply_count',
#        'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted',
#        'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df_tratado.drop(columns=['quote_count', 'reply_count','retweet_count', 'favorite_count', 'favorited', 'retweeted','user','entities'
                        ],inplace =True)

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'filter_level', 'lang',
#        'timestamp_ms'],
#       dtype='object')

# %%
df_tratado['user_id'] = primeirotweet['user']['id']
df_tratado['user_id_str'] = primeirotweet['user']['id_str']
df_tratado['user_screen_name'] = primeirotweet['user']['screen_name']
df_tratado['user_location'] = primeirotweet['user']['location']
df_tratado['user_description'] = primeirotweet['user']['description']
df_tratado['user_protected'] = primeirotweet['user']['protected']
df_tratado['user_verified'] = primeirotweet['user']['verified']
df_tratado['user_followers_count'] = primeirotweet['user']['followers_count']
df_tratado['user_friends_count'] = primeirotweet['user']['friends_count']
df_tratado['user_created_at'] = primeirotweet['user']['created_at']

# %%
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 22:27:36 +0000 2020  1330276705408323590  1330276705408323590
#
#                                                 text  \
# 0  Only 1433 hours until the end of Donald Trump'...
#
#                                               source  truncated  \
# 0  <a href="http://www.TrumpCountDownComingSoon.c...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...         user_id_str user_screen_name  \
# 0                    None  ...  822518858242134016  TrumpCountdown0
#
#               user_id   user_location  \
# 0  822518858242134016  Washington, DC
#
#                                     user_description  user_protected  \
# 0  The unofficial countdown for Donald Trump's pr...           False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                  354                  9
#
#                   user_created_at
# 0  Fri Jan 20 18:59:12 +0000 2017
#
# [1 rows x 29 columns]

# %%
# Entidades
primeirotweet['entities']
# Out:
# {'hashtags': [{'text': 'DontDrinkBleach', 'indices': [60, 76]},
#   {'text': 'ImpeachTrump', 'indices': [77, 90]},
#   {'text': 'TrumpCountdown', 'indices': [91, 106]},
#   {'text': 'BidenHarris2020', 'indices': [107, 123]}],
#  'urls': [],
#  'user_mentions': [],
#  'symbols': []}

# %%
user_mentions = []
for i in range(len(primeirotweet['entities']['user_mentions'])):
    print(i)

# %% [markdown]
# # Vamos criar uma funcção que faz todo o tratamento do tweet e converte para um dataframe pandas

# %%
def tweet_para_df(tweet):
    try:
        df_tratado = pd.DataFrame(tweet).reset_index(drop=True).iloc[:1]
        df_tratado.drop(columns=['quote_count', 'reply_count','retweet_count', 'favorite_count', 'favorited', 'retweeted','user','entities'
                            ],inplace =True)
        df_tratado['user_id'] = tweet['user']['id']
        df_tratado['user_id_str'] = tweet['user']['id_str']
        df_tratado['user_screen_name'] = tweet['user']['screen_name']
        df_tratado['user_location'] = tweet['user']['location']
        df_tratado['user_description'] = tweet['user']['description']
        df_tratado['user_protected'] = tweet['user']['protected']
        df_tratado['user_verified'] = tweet['user']['verified']
        df_tratado['user_followers_count'] = tweet['user']['followers_count']
        df_tratado['user_friends_count'] = tweet['user']['friends_count']
        df_tratado['user_created_at'] = tweet['user']['created_at']
    except:
        return None
        
    return df_tratado

# %%
tweet_para_df(parse_tweets)

# %%
# %%time
# Vamos interar e transformar todos os tweets
parseados = [tweet_para_df(tweet) for tweet in parse_tweets]
# Out:
# Wall time: 6min 51s

# %%
# Eliminar as posições vazias da lista
parseados = [i for i in parseados if i is not None]

# %%
tratado_final = pd.concat(parseados, ignore_index= True, sort=True)

# %%
tratado_final
# Out:
#      contributors coordinates                      created_at  \
# 0            None        None  Sat Nov 21 22:27:36 +0000 2020
# 1            None        None  Sat Nov 21 22:27:36 +0000 2020
# 2            None        None  Sat Nov 21 22:27:36 +0000 2020
# 3            None        None  Sat Nov 21 22:27:36 +0000 2020
# 4            None        None  Sat Nov 21 22:27:36 +0000 2020
# 5            None        None  Sat Nov 21 22:27:36 +0000 2020
# 6            None        None  Sat Nov 21 22:27:36 +0000 2020
# 7            None        None  Sat Nov 21 22:27:36 +0000 2020
# 8            None        None  Sat Nov 21 22:27:36 +0000 2020
# 9            None        None  Sat Nov 21 22:27:36 +0000 2020
# 10           None        None  Sat Nov 21 22:27:36 +0000 2020
# 11           None        None  Sat Nov 21 22:27:36 +0000 2020
# 12           None        None  Sat Nov 21 22:27:36 +0000 2020
# 13           None        None  Sat Nov 21 22:27:36 +0000 2020
# 14           None        None  Sat Nov 21 22:27:36 +0000 2020
# 15           None        None  Sat Nov 21 22:27:36 +0000 2020
# 16           None        None  Sat Nov 21 22:27:36 +0000 2020
# 17           None        None  Sat Nov 21 22:27:36 +0000 2020
# 18           None        None  Sat Nov 21 22:27:37 +0000 2020
# 19           None        None  Sat Nov 21 22:27:37 +0000 2020
# 20           None        None  Sat Nov 21 22:27:37 +0000 2020
# 21           None        None  Sat Nov 21 22:27:37 +0000 2020
# 22           None        None  Sat Nov 21 22:27:37 +0000 2020
# 23           None        None  Sat Nov 21 22:27:37 +0000 2020
# 24           None        None  Sat Nov 21 22:27:37 +0000 2020
# 25           None        None  Sat Nov 21 22:27:37 +0000 2020
# 26           None        None  Sat Nov 21 22:27:37 +0000 2020
# 27           None        None  Sat Nov 21 22:27:37 +0000 2020
# 28           None        None  Sat Nov 21 22:27:37 +0000 2020
# 29           None        None  Sat Nov 21 22:27:37 +0000 2020
# ...           ...         ...                             ...
# 4787         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4788         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4789         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4790         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4791         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4792         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4793         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4794         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4795         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4796         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4797         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4798         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4799         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4800         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4801         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4802         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4803         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4804         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4805         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4806         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4807         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4808         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4809         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4810         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4811         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4812         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4813         None        None  Sat Nov 21 22:29:29 +0000 2020
# 4814         None        None  Sat Nov 21 22:29:28 +0000 2020
# 4815         None        None  Sat Nov 21 22:29:29 +0000 2020
# 4816         None        None  Sat Nov 21 22:29:29 +0000 2020
#
#      extended_entities extended_tweet filter_level   geo                   id  \
# 0                  NaN            NaN          low  None  1330276705408323590
# 1                  NaN            NaN          low  None  1330276705420914689
# 2                  NaN            NaN          low  None  1330276705571893251
# 3                  NaN            NaN          low  None  1330276705555116032
# 4                  NaN            NaN          low  None  1330276705706127369
# 5                  NaN            NaN          low  None  1330276705668304899
# 6                  NaN            NaN          low  None  1330276705957765129
# 7                  NaN            NaN          low  None  1330276705936814082
# 8                  NaN            NaN          low  None  1330276705911644165
# 9                  NaN            NaN          low  None  1330276706054238209
# 10                 NaN            NaN          low  None  1330276706129686531
# 11                 NaN            NaN          low  None  1330276706465288196
# 12                 NaN            NaN          low  None  1330276706507239427
# 13                 NaN            NaN          low  None  1330276706402316291
# 14                 NaN            NaN          low  None  1330276706708566018
# 15                 NaN            NaN          low  None  1330276706909904896
# 16                 NaN            NaN          low  None  1330276706930864128
# 17                 NaN            NaN          low  None  1330276707115425797
# 18                 NaN            NaN          low  None  1330276707266400259
# 19                 NaN            NaN          low  None  1330276707245453314
# 20                 NaN            NaN          low  None  1330276707312553988
# 21                 NaN            NaN          low  None  1330276707497095178
# 22                 NaN            NaN          low  None  1330276707560009730
# 23                 NaN            NaN          low  None  1330276707497078784
# 24                 NaN            NaN          low  None  1330276707681652740
# 25                 NaN            NaN          low  None  1330276707526389760
# 26                 NaN            NaN          low  None  1330276707404746758
# 27                 NaN            NaN          low  None  1330276707606138880
# 28                 NaN            NaN          low  None  1330276707723599877
# 29                 NaN            NaN          low  None  1330276707622858752
# ...                ...            ...          ...   ...                  ...
# 4787               NaN            NaN          low  None  1330277174289555459
# 4788               NaN            NaN          low  None  1330277174394449920
# 4789               NaN            NaN          low  None  1330277174469865475
# 4790               NaN            NaN          low  None  1330277174633443328
# 4791               NaN            NaN          low  None  1330277174688030722
# 4792               NaN            NaN          low  None  1330277174725709833
# 4793               NaN            NaN          low  None  1330277174818074625
# 4794               NaN            NaN          low  None  1330277174759350272
# 4795               NaN            NaN          low  None  1330277174897762304
# 4796               NaN            NaN          low  None  1330277175036157952
# 4797               NaN            NaN          low  None  1330277175073927169
# 4798               NaN            NaN          low  None  1330277175229026307
# 4799               NaN            NaN          low  None  1330277175765970954
# 4800               NaN            NaN          low  None  1330277175405195266
# 4801               NaN            NaN          low  None  1330277175581347849
# 4802               NaN            NaN          low  None  1330277175833079808
# 4803               NaN            NaN          low  None  1330277175845670913
# 4804               NaN            NaN          low  None  1330277175929532423
# 4805               NaN            NaN          low  None  1330277175975702529
# 4806               NaN            NaN          low  None  1330277176046915586
# 4807               NaN            NaN          low  None  1330277175967297543
# 4808               NaN            NaN          low  None  1330277176063700993
# 4809               NaN            NaN          low  None  1330277176428683266
# 4810               NaN            NaN          low  None  1330277176298639363
# 4811               NaN            NaN          low  None  1330277176550322178
# 4812               NaN            NaN          low  None  1330277176734863360
# 4813               NaN            NaN          low  None  1330277177015857152
# 4814               NaN            NaN          low  None  1330277176885833728
# 4815               NaN            NaN          low  None  1330277177015808004
# 4816               NaN            NaN          low  None  1330277177338843141
#
#                    id_str in_reply_to_screen_name  ...  \
# 0     1330276705408323590                    None  ...
# 1     1330276705420914689                    None  ...
# 2     1330276705571893251                    None  ...
# 3     1330276705555116032                    None  ...
# 4     1330276705706127369                    None  ...
# 5     1330276705668304899                    None  ...
# 6     1330276705957765129                    None  ...
# 7     1330276705936814082                    None  ...
# 8     1330276705911644165                    None  ...
# 9     1330276706054238209                    None  ...
# 10    1330276706129686531                    None  ...
# 11    1330276706465288196                    None  ...
# 12    1330276706507239427                    None  ...
# 13    1330276706402316291                    None  ...
# 14    1330276706708566018                    None  ...
# 15    1330276706909904896                    None  ...
# 16    1330276706930864128                    None  ...
# 17    1330276707115425797                    None  ...
# 18    1330276707266400259                    None  ...
# 19    1330276707245453314                    None  ...
# 20    1330276707312553988                    None  ...
# 21    1330276707497095178                    None  ...
# 22    1330276707560009730                    None  ...
# 23    1330276707497078784                    None  ...
# 24    1330276707681652740                    None  ...
# 25    1330276707526389760                    None  ...
# 4806                875             17091056             17091056
# 4807                116   882914333575057408   882914333575057408
# 4808                194             56241270             56241270
# 4809                648  1242990546613829638  1242990546613829638
# 4810                676             33560406             33560406
# 4811               8525             28384772             28384772
# 4812               2883            450391029            450391029
# 4813                 96   823365767764684800   823365767764684800
# 4814                521            155915575            155915575
# 4815               5000  1176187638929350662  1176187638929350662
# 4816                550            179037253            179037253
#
#                     user_location user_protected user_screen_name  \
# 0                  Washington, DC          False  TrumpCountdown0
# 1                  Colchester, VT          False      markhaverty
# 2                      Dallas, TX          False        cdallas75
# 3                          Texas           False        ashbeth34
# 4                            None          False        Alborok75
# 5                            None          False         Bethass1
# 6                            None          False      StellaG1216
# 7                            None          False      pwilson1953
# 8                            None          False  LinklaterKerrie
# 9                            None          False        KenColon4
# 10       Scottsdale, Arizona, USA          False     sueettaparks
# 11                 Greenfield, IN          False    vickithenanny
# 12                    Nevada, USA          False  FightingFiresNV
# 13                           None          False     LisaDawn1618
# 14                         The EU          False      keefyclarke
# 15                 Washington, DC          False  Watchman1209007
# 16                           None          False  planetgreen2019
# 17                           None          False      NikkiJohn44
# 18                 Washington, DC          False      nowayhaitch
# 19                           None          False       briiittany
# 20                    Netherlands          False          eudoxos
# 21                Los Angeles, CA          False    SteffSiebrand
# 22                           None          False          Liane13
# 23                 Burlington, NC          False  DawnSim25976984
# 24    A Northwestern State in USA          False     limpinaround
# 25                  New York City          False     JAMESEDSTROM
# 26                     California          False           Ps5725
# 27            Alternative Reality          False    CaraTesoraMia
# 28                           None          False   TuNoticia_Info
# 29                           None          False  tankmanrebooted
# ...                           ...            ...              ...
# 4787                         None          False  Antonio54283865
# 4788              Oxford, England          False     suzy78772196
# 4789         Milky Way Galaxy USA          False         GNRtruth
# 4790                New York, USA          False       SaranMulan
# 4791                         None          False       Jacklrice2
# 4792                         None          False  JasonFr19476809
# 4793                  Madison, WI          False        Rells1977
# 4794   London/Shakespeare Country          False  publicradionerd
# 4795                 Florida, USA          False    MaritaWoods11
# 4796           Massachusetts, USA          False      Metafrantic
# 4797                           US          False        opusworks
# 4798                         None          False     barandazam__
# 4799                         None          False           euxprz
# 4800                         None          False          tat_tva
# 4801           Cliffs of Insanity          False   SarcasticBimbo
# 4802                   Durham, NC          False        wake_tfup
# 4803                         None          False    MARIEMANHARDT
# 4804                         None          False         lb_bklyn
# 4805                    Australia          False  6f6e5ba6bdc34ae
# 4806                         None          False         ene_liis
# 4807                         None          False      shkelly9142
# 4808   Tampa, FL via Marianna, FL          False      kweenthomas
# 4809                United States          False          QThis17
# 4810                    Minnesota          False          hhabben
# 4811                     Oklahoma          False    Connectionary
# 4812                San Diego, CA          False      christylnrd
# 4813                San Diego, CA          False    Flussigsebrot
# 4814           New Hampshire, USA          False     DesiresTacos
# 4815                         None          False  Gianfra79238417
# 4816         Melbourne, Australia          False            DPTOZ
#
#       user_verified
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False
# 15            False
# 16            False
# 17            False
# 18            False
# 19            False
# 20            False
# 21            False
# 22            False
# 23            False
# 24            False
# 25            False
# 26            False
# 27            False
# 28            False
# 29            False
# ...             ...
# 4787          False
# 4788          False
# 4789          False
# 4790          False
# 4791          False
# 4792          False
# 4793          False
# 4794          False
# 4795          False
# 4796          False
# 4797          False
# 4798          False
# 4799          False
# 4800          False
# 4801          False
# 4802          False
# 4803          False
# 4804          False
# 4805          False
# 4806          False
# 4807          False
# 4808          False
# 4809          False
# 4810          False
# 4811          False
# 4812          False
# 4813          False
# 4814          False
# 4815          False
# 4816          False
#
# [4817 rows x 37 columns]

# %% [markdown]
# # Ingestão de dados no twitter no SQL SERVER

# %%
# !pip install pyodbc update
# Out:
# Requirement already satisfied: pyodbc in c:\users\adria\anaconda3\lib\site-packages (4.0.26)
# Requirement already satisfied: update in c:\users\adria\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: style==1.1.0 in c:\users\adria\anaconda3\lib\site-packages (from update) (1.1.0)

# %%
import pyodbc
import sqlalchemy

# %%
engine = sqlalchemy.create_engine(
   'mssql+pyodbc://sa:99731162Aa@127.0.0.1/twitter?driver=ODBC+Driver+17+for+SQL+Server' 
)

# %%
# ingestão
tratado_final.to_sql('twetts',  con= engine, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pyodbc.py in do_executemany(self, cursor, statement, parameters, context)
#     346         super(MSDialect_pyodbc, self).do_executemany(
# --> 347             cursor, statement, parameters, context=context
#     348         )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     546     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 547         cursor.executemany(statement, parameters)
#     548
#
# ProgrammingError: ('Invalid parameter type.  param-index=16 param-type=dict', 'HY105')
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-112-3e2ff6075fa1> in <module>
#       1 # ingestão
# ----> 2 tratado_final.to_sql('twetts',  con= engine, index=False, if_exists='append')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     397     exc_type, exc_value, exc_tb = exc_info
#     398     cause = exc_value if exc_value is not exception else None
# --> 399     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     400
#     401
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151             value.__cause__ = cause
#     152         if value.__traceback__ is not tb:
# --> 153             raise value.with_traceback(tb)
#     154         raise value
#     155
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pyodbc.py in do_executemany(self, cursor, statement, parameters, context)
#     345             cursor.fast_executemany = True
#     346         super(MSDialect_pyodbc, self).do_executemany(
# --> 347             cursor, statement, parameters, context=context
#     348         )
#     349
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     545
#     546     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 547         cursor.executemany(statement, parameters)
#     548
#     549     def do_execute(self, cursor, statement, parameters, context=None):
#
# ProgrammingError: (pyodbc.ProgrammingError) ('Invalid parameter type.  param-index=16 param-type=dict', 'HY105')
# [SQL: INSERT INTO twetts (contributors, coordinates, created_at, extended_entities, extended_tweet, filter_level, geo, id, id_str, in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, is_quote_status, lang, place, possibly_sensitive, quoted_status, quoted_status_id, quoted_status_id_str, quoted_status_permalink, retweeted_status, source, text, timestamp_ms, truncated, user_created_at, user_description, user_followers_count, user_friends_count, user_id, user_id_str, user_location, user_protected, user_screen_name, user_verified) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ((None, None, 'Sat Nov 21 22:27:36 +0000 2020', None, None, 'low', None, 1330276705408323590, '1330276705408323590', None, None, None, None, None, 0, 'en', None, None, None, None, None, None, None, '<a href="http://www.TrumpCountDownComingSoon.com" rel="nofollow">The Trump Count Down</a>', "Only 1433 hours until the end of Donald Trump's presidency! #DontDrinkBleach #ImpeachTrump #TrumpCountdown #BidenHarris2020", '1605997656572', 0, 'Fri Jan 20 18:59:12 +0000 2017', "The unofficial countdown for Donald Trump's presidency.", 354, 9, 822518858242134016, '822518858242134016', 'Washington, DC', 0, 'TrumpCountdown0', 0), (None, None, 'Sat Nov 21 22:27:36 +0000 2020', None, None, 'low', None, 1330276705420914689, '1330276705420914689', None, None, None, None, None, 0, 'en', None, None, None, None, None, None, None, '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'RT @AndrewSolender: Trump attorney holds GOP’s only chance at an elected lever of power over the cliff-edge to win an election that’s alrea…', '1605997656575', 0, 'Fri Sep 26 20:57:09 +0000 2008', 'Tweets about my loves: comics, sports, politics, and esp. my daughter. Former writer for FOX Sports, Sporting News, and Wizard magazine, amongst others.', 331, 531, 16474685, '16474685', 'Colchester, VT', 0, 'markhaverty', 0), (None, None, 'Sat Nov 21 22:27:36 +0000 2020', None, None, 'low', None, 1330276705571893251, '1330276705571893251', None, None, None, None, None, 0, 'en', None, None, None, None, None, None, None, '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'RT @JohnWDean: Trump is openly and actively violating federal criminal laws in his efforts to overturn his defeat. President-elect Biden sh…', '1605997656611', 0, 'Wed May 17 16:18:14 +0000 2017', '#BidenHarris2020, Betocrat, Still with HRC, #votetxblue #RBGRevolution,#planyourvote #voteearly please no DM 🏴\u200d☠️', 3127, 4995, 864877729426145280, '864877729426145280', 'Dallas, TX', 0, 'cdallas75', 0), (None, None, 'Sat Nov 21 22:27:36 +0000 2020', None, None, 'low', None, 1330276705555116032, '1330276705555116032', None, None, None, None, None, 0, 'en', None, None, None, None, None, None, None, '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'RT @TRUMPMOMENTS411: @NewDayForNJ Yes, it is. The Son of Kraken was the press conference, and Trump is sitting back right now watching the…', '1605997656607', 0, 'Thu Jul 09 02:28:47 +0000 2009', '#KAG\n#ThinBlueLine', 5634, 4801, 55113653, '55113653', 'Texas ', 0, 'ashbeth34', 0), (None, None, 'Sat Nov 21 22:27:36 +0000 2020', None, None, 'low', None, 1330276705706127369, '1330276705706127369', None, None, None, None, None, 0, 'en', None, None, None, None, None, None, None, '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'RT @realTuckFrumper: George Conway’s PERFECT Analogy for Trump is Going Viral — Loved So Much Thousands are Responding https://t.co/MkXmUIo…', '1605997656643', 0, 'Sun Oct 26 13:27:27 +0000 2014', None, 281, 493, 2878276560, '2878276560', None, 0, 'Alborok75', 0), (None, None, 'Sat Nov 21 22:27:36 +0000 2020', None, None, 'low', None, 1330276705668304899, '1330276705668304899', None, None, None, None, None, 0, 'en', None, None, None, None, None, None, None, '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', "RT @JohnLukeSam1: What a stubborn lazy spiteful fat old sick man Trump is. He skips today's G20 summit that's focused on COVID to once agai…", '1605997656634', 0, 'Wed Jan 09 00:13:46 +0000 2019', 'Wife, mom, super dog lover, and a never, ever ever trumper.  He’s got to go.', 211, 352, 1082792508873211907, '1082792508873211907', None, 0, 'Bethass1', 0), (None, None, 'Sat Nov 21 22:27:36 +0000 2020', None, None, 'low', None, 1330276705957765129, '1330276705957765129', None, None, None, None, None, 0, 'en', None, None, None, None, None, None, None, '<a href="http://twitter.com/download/iphone ...
# (Background on this error at: http://sqlalche.me/e/f405)
